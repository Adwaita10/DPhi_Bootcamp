# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Task 1

# %%
##Reading the dataset and naming it as df
df = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/covid_19_data.csv")
df.head()
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
df.head(10) ##Printing first 10 observations of the dataset
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
# 5    6      01/22/2020      Guangdong  Mainland China  1/22/2020 17:00
# 6    7      01/22/2020        Guangxi  Mainland China  1/22/2020 17:00
# 7    8      01/22/2020        Guizhou  Mainland China  1/22/2020 17:00
# 8    9      01/22/2020         Hainan  Mainland China  1/22/2020 17:00
# 9   10      01/22/2020          Hebei  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# ...

# %%
#Checking datatype of all the the variables in the dataset
df.dtypes
# Out:
# SNo                  int64
# ObservationDate     object
# Province/State      object
# Country/Region      object
# Last Update         object
# Confirmed          float64
# Deaths             float64
# Recovered          float64
# dtype: object

# %%
#Convert columns ['ObservationDate'] and ['Last Update'] from object to datatime data type.
df['ObservationDate'] = pd.to_datetime(df['ObservationDate'])
df['Last Update'] = pd.to_datetime(df['Last Update'])

# %%
df.dtypes
# Out:
# SNo                         int64
# ObservationDate    datetime64[ns]
# Province/State             object
# Country/Region             object
# Last Update        datetime64[ns]
# Confirmed                 float64
# Deaths                    float64
# Recovered                 float64
# dtype: object

# %% [markdown]
# # Task 2

# %%
df.head()
# Out:
#    SNo ObservationDate Province/State  Country/Region         Last Update  \
# 0    1      2020-01-22          Anhui  Mainland China 2020-01-22 17:00:00
# 1    2      2020-01-22        Beijing  Mainland China 2020-01-22 17:00:00
# 2    3      2020-01-22      Chongqing  Mainland China 2020-01-22 17:00:00
# 3    4      2020-01-22         Fujian  Mainland China 2020-01-22 17:00:00
# 4    5      2020-01-22          Gansu  Mainland China 2020-01-22 17:00:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
updated_data = df[df['Last Update'] == '2020-06-13 03:33:14' ]
updated_data.head()
# Out:
#          SNo ObservationDate Province/State Country/Region  \
# 40076  40077      2020-06-12            NaN    Afghanistan
# 40077  40078      2020-06-12            NaN        Albania
# 40078  40079      2020-06-12            NaN        Algeria
# 40079  40080      2020-06-12            NaN        Andorra
# 40080  40081      2020-06-12            NaN         Angola
#
#               Last Update  Confirmed  Deaths  Recovered
# 40076 2020-06-13 03:33:14    23546.0   446.0     3928.0
# 40077 2020-06-13 03:33:14     1416.0    36.0     1034.0
# 40078 2020-06-13 03:33:14    10698.0   751.0     7322.0
# 40079 2020-06-13 03:33:14      853.0    51.0      781.0
# 40080 2020-06-13 03:33:14      130.0     5.0       42.0

# %%
updated_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 729 entries, 40076 to 40804
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   SNo              729 non-null    int64
#  1   ObservationDate  729 non-null    datetime64[ns]
#  2   Province/State   560 non-null    object
#  3   Country/Region   729 non-null    object
#  4   Last Update      729 non-null    datetime64[ns]
#  5   Confirmed        729 non-null    float64
#  6   Deaths           729 non-null    float64
#  7   Recovered        729 non-null    float64
# dtypes: datetime64[ns](2), float64(3), int64(1), object(2)
# memory usage: 51.3+ KB

# %%
#Total no. of observations
NO_of_observations = len(updated_data.index)
print(NO_of_observations)
# Out:
# 729

# %%
#Number of unique country records
unique_countries = updated_data.groupby('Country/Region')
print(len(unique_countries))
# Out:
# 190

# %%
unique_countries.first()
# Out:
#                       SNo ObservationDate Province/State         Last Update  \
# Country/Region
# Afghanistan         40077      2020-06-12            NaN 2020-06-13 03:33:14
# Albania             40078      2020-06-12            NaN 2020-06-13 03:33:14
# Algeria             40079      2020-06-12            NaN 2020-06-13 03:33:14
# Andorra             40080      2020-06-12            NaN 2020-06-13 03:33:14
# Angola              40081      2020-06-12            NaN 2020-06-13 03:33:14
# ...                   ...             ...            ...                 ...
# West Bank and Gaza  40241      2020-06-12            NaN 2020-06-13 03:33:14
# Western Sahara      40242      2020-06-12            NaN 2020-06-13 03:33:14
# Yemen               40243      2020-06-12            NaN 2020-06-13 03:33:14
# Zambia              40244      2020-06-12            NaN 2020-06-13 03:33:14
# Zimbabwe            40245      2020-06-12            NaN 2020-06-13 03:33:14
#
# ...

# %% [markdown]
# # Task 3

# %%
top_10 = unique_countries.agg('sum')
top_10 = top_10.sort_values('Confirmed',ascending = False).head(10)
del top_10['SNo']
top_10
# Out:
#                 Confirmed    Deaths  Recovered
# Country/Region
# US              2048986.0  114669.0   547386.0
# Brazil           828810.0   41828.0   445123.0
# Russia           510761.0    6705.0   268862.0
# India            297535.0    8498.0   147195.0
# UK               294402.0   41566.0     1282.0
# Spain            243209.0   27136.0   150376.0
# Italy            236305.0   34223.0   173085.0
# Peru             214788.0    6088.0   107133.0
# France           193220.0   29377.0    72695.0
# Germany          187226.0    8783.0   171535.0

# %%
#Printing the country which has the lowest number of confirmed cases among the ten countries in top_10 dataframe
top_10.tail(1)
# Out:
#                 Confirmed  Deaths  Recovered
# Country/Region
# Germany          187226.0  8783.0   171535.0

# %%
# Germany has the least number of confirmed cases among the top_10 dataframe

# %% [markdown]
# # Task 4

# %%
top_10['Recovered_percentage'] = (top_10['Recovered']/top_10['Confirmed'])*100
top_10['Deaths_percentage'] = (top_10['Deaths']/top_10['Confirmed'])*100
top_10
# Out:
#                 Confirmed    Deaths  Recovered  Recovered_percentage  \
# Country/Region
# US              2048986.0  114669.0   547386.0             26.714970
# Brazil           828810.0   41828.0   445123.0             53.706278
# Russia           510761.0    6705.0   268862.0             52.639493
# India            297535.0    8498.0   147195.0             49.471491
# UK               294402.0   41566.0     1282.0              0.435459
# Spain            243209.0   27136.0   150376.0             61.829949
# Italy            236305.0   34223.0   173085.0             73.246440
# Peru             214788.0    6088.0   107133.0             49.878485
# France           193220.0   29377.0    72695.0             37.622917
# Germany          187226.0    8783.0   171535.0             91.619220
#
#                 Deaths_percentage
# Country/Region
# US                       5.596378
# Brazil                   5.046754
# Russia                   1.312747
# India                    2.856135
# ...

# %%
top_3 = top_10.sort_values('Recovered_percentage',ascending = False).head(3)
top_3
# Out:
#                 Confirmed   Deaths  Recovered  Recovered_percentage  \
# Country/Region
# Germany          187226.0   8783.0   171535.0             91.619220
# Italy            236305.0  34223.0   173085.0             73.246440
# Spain            243209.0  27136.0   150376.0             61.829949
#
#                 Deaths_percentage
# Country/Region
# Germany                  4.691122
# Italy                   14.482554
# Spain                   11.157482
